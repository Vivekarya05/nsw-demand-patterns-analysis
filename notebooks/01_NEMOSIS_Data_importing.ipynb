# %% [markdown]
# # NSW Electricity Demand Analysis
# ## Case Study 1: Daily, Weekly, Seasonal Demand Patterns
#
# This notebook performs exploratory data analysis (EDA) on NSW operational demand data
# to understand daily cycles, weekly behaviour, and seasonal trends.
#
# Dataset Source: AEMO Operational Demand (via Python library or uploaded dataset)
# Region: NSW1
# Timeframe: YYYY-YYYY (fill after loading data)

# %%
# Step 1: Import necessary library files and set up cache
import pandas as pd
from nemosis import dynamic_data_compiler
from datetime import datetime, timedelta
import os
from pymongo import MongoClient

# --- Cache Setup ---
# A temporary directory to store AEMO CSV files downloaded by nemosis
raw_data_cache_dir = "/tmp/nemosis_cache"
os.makedirs(raw_data_cache_dir, exist_ok=True)
print(f"Cache directory ensured: {raw_data_cache_dir}")

# --- AEMO Table Name ---
# We will use DISPATCHREGIONSUM for reliable regional demand data
table_name = "DISPATCHREGIONSUM"

# --- Date range setup ---
start_date = datetime(2024, 1, 1)
end_date = datetime(2025, 1, 1)
print(f"Data range defined from {start_date.date()} to {end_date.date()}")
# Out:
# Cache directory ensured: /tmp/nemosis_cache
# Data range defined from 2024-01-01 to 2025-01-01

# %%
# Step 2: Connect to MongoDB
try:
    client = MongoClient("mongodb://localhost:27017/")
    # Access the database and collection
    db = client["AEMO_Data_Archive"]
    collection = db["NSW_Operational_Demand_2024"]
    
    # Optional: Check connection by listing existing collections
    print(f"Connected to MongoDB. Collections in 'AEMO_Data_Archive': {db.list_collection_names()}")
    print(f"Target collection is '{collection.name}'.")

except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")
    print("Please ensure your MongoDB service (mongod) is running on localhost:27017.")
    # If connection fails, the script might stop here depending on your environment.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       6     collection = db["NSW_Operational_Demand_2024"]
#       8     # Optional: Check connection by listing existing collections
# ----> 9     print(f"Connected to MongoDB. Collections in 'AEMO_Data_Archive': {db.list_collection_names()}")
#      10     print(f"Target collection is '{collection.name}'.")
#      12 except Exception as e:
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/database.py:1226, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1194 def list_collection_names(
#    1195     self,
#    1196     session: Optional[ClientSession] = None,
#    (...)
#    1199     **kwargs: Any,
#    1200 ) -> list[str]:
#    1201     """Get a list of all the collection names in this database.
#    1202
#    1203     For example, to list all non-system collections::
#    (...)
#    1224     .. versionadded:: 3.6
#    1225     """
# -> 1226     return self._list_collection_names(session, filter, comment, **kwargs)
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/database.py:1191, in Database._list_collection_names(self, session, filter, comment, **kwargs)
#    1187     if not filter or (len(filter) == 1 and "name" in filter):
#    1188         kwargs["nameOnly"] = True
#    1190 return [
# -> 1191     result["name"] for result in self._list_collections_helper(session=session, **kwargs)
#    1192 ]
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/database.py:1138, in Database._list_collections_helper(self, session, filter, comment, **kwargs)
#    1130 def _cmd(
#    1131     session: Optional[ClientSession],
#    1132     _server: Server,
#    1133     conn: Connection,
#    1134     read_preference: _ServerMode,
#    1135 ) -> CommandCursor[MutableMapping[str, Any]]:
#    1136     return self._list_collections(conn, session, read_preference=read_preference, **kwargs)
# -> 1138 return self._client._retryable_read(
#    1139     _cmd, read_pref, session, operation=_Op.LIST_COLLECTIONS
#    1140 )
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1861, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1856 # Ensure that the client supports retrying on reads and there is no session in
#    1857 # transaction, otherwise, we will not support retry behavior for this call.
#    1858 retryable = bool(
#    1859     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1860 )
# -> 1861 return self._retry_internal(
#    1862     func,
#    1863     session,
#    1864     None,
#    1865     operation,
#    1866     is_read=True,
#    1867     address=address,
#    1868     read_pref=read_pref,
#    1869     retryable=retryable,
#    1870     operation_id=operation_id,
#    1871 )
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2700, in _ClientConnectionRetryable._read(self)
#    2695 def _read(self) -> T:
#    2696     """Wrapper method for read-type retryable client executions
#    2697
#    2698     :return: Output for func()'s call
#    2699     """
# -> 2700     self._server = self._get_server()
#    2701     assert self._read_pref is not None, "Read Preference required on read calls"
#    2702     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2703         conn,
#    2704         read_pref,
#    2705     ):
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2656, in _ClientConnectionRetryable._get_server(self)
#    2651 def _get_server(self) -> Server:
#    2652     """Retrieves a server object based on provided object context
#    2653
#    2654     :return: Abstraction to connect to server
#    2655     """
# -> 2656     return self._client._select_server(
#    2657         self._server_selector,
#    2658         self._session,
#    2659         self._operation,
#    2660         address=self._address,
#    2661         deprioritized_servers=self._deprioritized_servers,
#    2662         operation_id=self._operation_id,
#    2663     )
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1647, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1645             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1646     else:
# -> 1647         server = topology.select_server(
#    1648             server_selector,
#    1649             operation,
#    1650             deprioritized_servers=deprioritized_servers,
#    1651             operation_id=operation_id,
#    1652         )
#    1653     return server
#    1654 except PyMongoError as exc:
#    1655     # Server selection errors in a transaction are transient.
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/topology.py:401, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     391 def select_server(
#     392     self,
#     393     selector: Callable[[Selection], Selection],
#    (...)
#     398     operation_id: Optional[int] = None,
#     399 ) -> Server:
#     400     """Like select_servers, but choose a random server if several match."""
# --> 401     server = self._select_server(
#     402         selector,
#     403         operation,
#     404         server_selection_timeout,
#     405         address,
#     406         deprioritized_servers,
#     407         operation_id=operation_id,
#     408     )
#     409     if _csot.get_timeout():
#     410         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/topology.py:379, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     370 def _select_server(
#     371     self,
#     372     selector: Callable[[Selection], Selection],
#    (...)
#     377     operation_id: Optional[int] = None,
#     378 ) -> Server:
# --> 379     servers = self.select_servers(
#     380         selector, operation, server_selection_timeout, address, operation_id
#     381     )
#     382     servers = _filter_servers(servers, deprioritized_servers)
#     383     if len(servers) == 1:
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/topology.py:286, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     283     server_timeout = server_selection_timeout
#     285 with self._lock:
# --> 286     server_descriptions = self._select_servers_loop(
#     287         selector, server_timeout, operation, operation_id, address
#     288     )
#     290     return [
#     291         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     292     ]
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/topology.py:360, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     354 self._request_check_all()
#     356 # Release the lock and wait for the topology description to
#     357 # change, or for a timeout. We won't miss any changes that
#     358 # came after our most recent apply_selector call, since we've
#     359 # held the lock until now.
# --> 360 _cond_wait(self._condition, common.MIN_HEARTBEAT_INTERVAL)
#     361 self._description.check_compatible()
#     362 now = time.monotonic()
#
# File /Users/anaconda3/lib/python3.12/site-packages/pymongo/lock.py:92, in _cond_wait(condition, timeout)
#      91 def _cond_wait(condition: threading.Condition, timeout: Optional[float]) -> bool:
# ---> 92     return condition.wait(timeout)
#
# File /Users/anaconda3/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Step 3: Loop through data month-by-month and ingest into MongoDB
current = start_date

print("\n--- Starting Data Ingestion Loop ---")

while current < end_date:
    # Calculate the next month's start and end dates accurately
    next_month = (current.replace(day=28) + timedelta(days=4)).replace(day=1)
    end_of_month = next_month - timedelta(seconds=1) 
    
    start_str = current.strftime("%Y/%m/%d %H:%M:%S")
    end_str = end_of_month.strftime("%Y/%m/%d %H:%M:%S")
    
    print(f"\nProcessing {start_str} → {end_str} for {table_name}...")

    try:
        df = dynamic_data_compiler(
            start_str,
            end_str,
            table_name,
            raw_data_cache_dir
        )
        
        # Filter for the NSW region using the verified 'REGIONID' column
        if 'REGIONID' in df.columns:
            df_nsw = df[df["REGIONID"] == "NSW1"].copy()
            
            if not df_nsw.empty:
                # Insert into MongoDB
                records = df_nsw.to_dict("records")
                result = collection.insert_many(records)
                print(f"Inserted {len(result.inserted_ids)} documents for NSW1 in {current.strftime('%B %Y')}.")
            else:
                print(f"No NSW1 specific data found for this period.")
        else:
            print(f"Error: 'REGIONID' column not found in the {table_name} data frame.")

        del df # Release memory
        
    except Exception as e:
        print(f"An error occurred while processing {current.strftime('%B %Y')}: {e}")
        # Continue to the next month even if one month fails
        pass

    current = next_month

print("\n--- Data ingestion complete! ---")

# %%
cursor = collection.find({})
df = pd.DataFrame(list(cursor))

df.head()
df.info()
df.columns

# %%
df.head()

# %%
df_analysis = df[['SETTLEMENTDATE', 'TOTALDEMAND']]

# %%
df_analysis.head()

# %%
df_analysis['SETTLEMENTDATE'] = pd.to_datetime(df['SETTLEMENTDATE'])

df_analysis['hour'] = dfdfdf['SETTLEMENTDATE'].dt.hour
df_analysis['day'] = dfdf['SETTLEMENTDATE'].dt.day
df_analysis['weekday'] = df['SETTLEMENTDATE'].dt.day_name()
df_analysis['month'] = df['SETTLEMENTDATE'].dt.month
df_analysis['month_name'] = df['SETTLEMENTDATE'].dt.month_name()
df_analysis['date'] = df['SETTLEMENTDATE'].dt.date

# %%
df_analysis.head()

# %%
df_analysis['season'] = df_analysis['SETTLEMENTDATE'].dt.month % 12 // 3 + 1
df_analysis['season_name'] = df_analysis['season'].map({
    1: 'Summer',
    2: 'Autumn',
    3: 'Winter',
    4: 'Spring'
})

# %%
df_analysis.head()

# %%
df_analysis.info()
